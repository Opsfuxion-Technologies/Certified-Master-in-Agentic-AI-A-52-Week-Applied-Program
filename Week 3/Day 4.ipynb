# %% [markdown]
# # DAY 4: Understanding the Core Engine Behind Agents: How Large Language Models Think
# ## Lab 1: Visualizing Tokenization and Embeddings
# ### Goal: Understand how text is broken into tokens and converted into embeddings (numerical vectors). Learn to visualize and interpret these structures.
# - Estimated Time: 90–120 minutes
# - Deliverable: Notebook/plots showing token breakdown and a 2D embedding visualization.

# %%
# Install libraries:

# !pip install openai tiktoken matplotlib scikit-learn
# Out:
# Requirement already satisfied: openai in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (1.109.1)
# Requirement already satisfied: tiktoken in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (0.12.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (2.12.0)
# Requirement already satisfied: sniffio in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from tiktoken) (2025.9.18)
# Requirement already satisfied: requests>=2.26.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from tiktoken) (2.32.5)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 2.1 MB/s  0:00:03m 2.1 MB/s eta 0:00:01
# Downloading scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 3.7 MB/s  0:00:02m 3.7 MB/s eta 0:00:01
# Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 5.4 MB/s  0:00:00m 5.4 MB/s eta 0:00:01
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 8.5 MB/s  0:00:02 eta 0:00:010:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, pyparsing, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [matplotlib]0m  9/10 [matplotlib]n]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 joblib-1.5.2 kiwisolver-1.4.9 matplotlib-3.10.7 pyparsing-3.2.5 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Step 2. Inspect Tokenization
# - Use tiktoken (OpenAI’s tokenizer)

# %%
import tiktoken
 
enc = tiktoken.encoding_for_model("gpt-4o-mini")
 
sample_text = "Agentic AI agents can plan, reason, and use tools."
tokens = enc.encode(sample_text)
 
print("Original text:", sample_text)
print("Number of tokens:", len(tokens))
print("Token IDs:", tokens)
print("Decoded tokens:", [enc.decode([t]) for t in tokens])

# Try different texts: long sentences, code snippets, emojis.
# Observe how punctuation, spaces, and symbols affect token count.
# Out:
# Original text: Agentic AI agents can plan, reason, and use tools.
# Number of tokens: 13
# Token IDs: [18086, 291, 20837, 19297, 665, 3496, 11, 5207, 11, 326, 1199, 8437, 13]
# Decoded tokens: ['Agent', 'ic', ' AI', ' agents', ' can', ' plan', ',', ' reason', ',', ' and', ' use', ' tools', '.']

# %% [markdown]
# ### 3. Compare Token Length Across Texts
# - Note how shorthand, abbreviations, or emojis impact tokens

# %%
sentences = [
    "AI is amazing.",
    "Artificial Intelligence is amazing.",
    "AI is 🔥."
]
 
for s in sentences:
    t = enc.encode(s)
    print(f"Text: {s}\nTokens: {len(t)} → {t}\n")
# Out:
# Text: AI is amazing.
# Tokens: 4 → [17527, 382, 8467, 13]
#
# Text: Artificial Intelligence is amazing.
# Tokens: 5 → [186671, 42378, 382, 8467, 13]
#
# Text: AI is 🔥.
# Tokens: 5 → [17527, 382, 113718, 98, 13]

# %% [markdown]
# ### Step 4. Generate Embeddings
# - Use OpenAI embeddings:

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
 
client = OpenAI()
 
texts = ["Agentic AI", "Autonomous agents", "Bananas are yellow"]
 
embeddings = []
for t in texts:
    resp = client.embeddings.create(
        model="text-embedding-3-small",
        input=t
    )
    vector = resp.data[0].embedding
    embeddings.append(vector)
    print(f"{t} → vector length {len(vector)}")
    
# Notice embedding dimensions (e.g., 1536).
# Out:
# Agentic AI → vector length 1536
# Autonomous agents → vector length 1536
# Bananas are yellow → vector length 1536

# %% [markdown]
# ### Step 5. Dimensionality Reduction & Plotting (25 min)
# - Visualize embeddings in 2D space:

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
 
pca = PCA(n_components=2)
points = pca.fit_transform(embeddings)
 
plt.figure(figsize=(6,6))
for i, txt in enumerate(texts):
    plt.scatter(points[i,0], points[i,1])
    plt.text(points[i,0]+0.02, points[i,1]+0.02, txt)
 
plt.title("Embedding Visualization (PCA 2D)")
plt.show()

# Add more sentences and observe clusters.
# Try semantically similar phrases vs unrelated ones.
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Step 6. Experiment with Semantic Similarity (15 min)
# - Compute cosine similarity:

# %%
# Compute cosine similarity:

from sklearn.metrics.pairwise import cosine_similarity
 
sim = cosine_similarity([embeddings[0]], embeddings)
print("Similarity scores:", sim)

# Compare "Agentic AI" vs "Autonomous agents" vs "Bananas are yellow".
# Similar texts should yield higher similarity scores.
# Out:
# Similarity scores: [[1.         0.58418607 0.02983828]]

# %% [markdown]
# ### Step 7. Mini-Project: Token & Embedding Explorer (15–20 min)
# - Write a small function:
# - Input: a sentence.
#
# - Output: tokens + embedding + similarity vs a reference.
# - Test with multiple sentences and visualize clusters again.
#
# - By finishing this lab, you’ll see how raw text becomes numbers via tokenization and embeddings:
# — the foundation of LLM reasoning and semantic search / RAG pipelines.
