# %% [markdown]
# # Day 6: Fine-Tuning vs Adapters vs RAG – Hands-On Comparison
# ## Goal: Compare how fine-tuning, adapters, and RAG solve the same problem: making an LLM answer domain-specific questions.
# ### Deliverable: Notebook/scripts showing Q&A results from all three strategies.

# %% [markdown]
# ### Step 1: Setup
# - Install necessary libraries

# %%
pip install openai datasets transformers faiss-cpu langchain chromadb
# Out:
# Requirement already satisfied: openai in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (1.109.1)
# Collecting datasets
#   Using cached datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Collecting transformers
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: faiss-cpu in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (1.12.0)
# Requirement already satisfied: langchain in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (0.3.27)
# Requirement already satisfied: chromadb in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (2.12.0)
# Requirement already satisfied: sniffio in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: filelock in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (21.0.0)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (2.32.5)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.6.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Using cached multiprocess-0.70.18-py313-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (0.35.3)
# Requirement already satisfied: packaging in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.1.10)
# Requirement already satisfied: regex!=2019.12.17 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (0.22.1)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.6.2-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langchain) (0.3.78)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langchain) (0.4.33)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langchain) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: build>=1.0.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.37.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (1.23.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: pyproject_hooks in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.41.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.1)
# Requirement already satisfied: sympy in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Using cached datasets-4.4.1-py3-none-any.whl (511 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached multiprocess-0.70.18-py313-none-any.whl (151 kB)
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Using cached safetensors-0.6.2-cp38-abi3-macosx_11_0_arm64.whl (432 kB)
# Downloading xxhash-3.6.0-cp313-cp313-macosx_11_0_arm64.whl (30 kB)
# Installing collected packages: xxhash, safetensors, dill, multiprocess, transformers, datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [datasets]━━ 5/6 [datasets]ansformers]
# Successfully installed datasets-4.4.1 dill-0.4.0 multiprocess-0.70.18 safetensors-0.6.2 transformers-4.57.1 xxhash-3.6.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 2: Define a Simple Knowledge Base
# - We’ll pretend our model needs to know facts about Agentic AI.

# %%
kb = [
    "Agentic AI agents use memory, tools, and goals to act.",
    "LangChain and CrewAI are popular frameworks for building AI agents.",
    "Retrieval-Augmented Generation (RAG) improves accuracy by fetching external knowledge."
]
questions = [
    "What are the key components of Agentic AI?",
    "Name one framework for AI agents.",
    "How does RAG improve answers?"
]

# %% [markdown]
# ### Step 3: Fine-Tuning (Conceptual Demo, 20 min)
# - Fine-tuning = updating model weights with new labeled examples.

# %%
from datasets import Dataset
 
train_data = Dataset.from_dict({
    "prompt": [
        "Q: What are the key components of Agentic AI?\nA:",
        "Q: Name one framework for AI agents.\nA:",
        "Q: How does RAG improve answers?\nA:"
    ],
    "completion": [
        " Agentic AI agents use memory, tools, and goals to act.",
        " LangChain is a framework for building AI agents.",
        " RAG improves accuracy by fetching external knowledge before answering."
    ]
})
print(train_data)
# Out:
# Dataset({
#     features: ['prompt', 'completion'],
#     num_rows: 3
# })

# %% [markdown]
# #### With OpenAI or Hugging Face, you’d upload this dataset for fine-tuning.
# - Downside: time, cost, retraining needed for updates.

# %% [markdown]
# ### Step 4: Adapters / LoRA (Conceptual Demo, 20 min)
# - Adapters = small parameter-efficient layers you train instead of the whole model.

# %%
# !pip install torch --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.9.0-cp313-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.9.0-cp313-none-macosx_11_0_arm64.whl (74.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 6.8 MB/s  0:00:11 eta 0:00:010:01:01
# Installing collected packages: torch
# Successfully installed torch-2.9.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.9.0
# CUDA available: False

# %%
import torch
print("PyTorch version:", torch.__version__)
# Out:
# PyTorch version: 2.9.0

# %%
import sys
print(sys.executable)
# Out:
# /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/bin/python

# %%
pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (4.57.1)
# Requirement already satisfied: filelock in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/agentic_env/lib/python3.13/site-packages (from requests->transformers) (2025.10.5)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers.utils import is_torch_available, is_tf_available, is_flax_available

print("PyTorch available:", is_torch_available())
print("TensorFlow available:", is_tf_available())
print("Flax available:", is_flax_available())
# Out:
# PyTorch available: True
# TensorFlow available: False
# Flax available: False

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
 
model_name = "distilgpt2"
tok = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
 
print("Base model loaded:", model_name)
print("With LoRA/adapters, you’d only train a few million params instead of billions.")

# Adapters are flexible + cheaper than full fine-tuning.
# But still require training infra (not run here).
# Out:
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Base model loaded: distilgpt2
# With LoRA/adapters, you’d only train a few million params instead of billions.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "distilgpt2"
tok = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print("Base model loaded:", model_name)
print("With LoRA/adapters, you’d only train a few million params instead of billions.")
# Out:
# Base model loaded: distilgpt2
# With LoRA/adapters, you’d only train a few million params instead of billions.

# %% [markdown]
# ### Step 5: RAG – Hands-On (30 min)
# - Unlike training, RAG fetches external knowledge at runtime. Let’s build one.

# %%
# Define a simple knowledge base
kb = [
    "Agentic AI agents use memory, tools, and goals to act.",
    "LangChain and CrewAI are popular frameworks for building AI agents.",
    "Retrieval-Augmented Generation (RAG) improves accuracy by fetching external knowledge."
]

# Define questions to test the retriever
questions = [
    "What are the key components of Agentic AI?",
    "Name one framework for AI agents.",
    "How does RAG improve answers?"
]

# %%
from dotenv import load_dotenv
import os

# Explicitly tell dotenv where to find your .env (optional but safe)
env_path = "/Users/marameref/Desktop/Certified-Master-in-Agentic-AI-A-52-Week-Applied-Program/.env"
load_dotenv(dotenv_path=env_path)

# Confirm
print("✅ .env loaded:", os.path.exists(env_path))
print("✅ Key found:", os.getenv("OPENAI_API_KEY") is not None)
# Out:
# ✅ .env loaded: True
# ✅ Key found: True

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.docstore.document import Document
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
 
# Build vector DB
docs = [Document(page_content=x) for x in kb]
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(docs, embeddings)
 
retriever = db.as_retriever()
qa = RetrievalQA.from_chain_type(
    llm=ChatOpenAI(model="gpt-4o-mini"),
    retriever=retriever
)
 
for q in questions:
    print("\nQ:", q)
    print("A:", qa.run(q))
# Out:
# /var/folders/xs/v8v3y1ss79g81v1_kr8sbw5m0000gn/T/ipykernel_59222/2920547854.py:14: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm=ChatOpenAI(model="gpt-4o-mini"),
# /var/folders/xs/v8v3y1ss79g81v1_kr8sbw5m0000gn/T/ipykernel_59222/2920547854.py:20: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   print("A:", qa.run(q))
# Q: What are the key components of Agentic AI?
# A: The key components of Agentic AI include memory, tools, and goals.
#
# Q: Name one framework for AI agents.
# A: LangChain is one framework for AI agents.
#
# Q: How does RAG improve answers?
# A: Retrieval-Augmented Generation (RAG) improves answers by fetching external knowledge to enhance the accuracy and relevance of the information provided. It combines the strengths of retrieval-based and generative models, allowing the system to access up-to-date and contextually relevant information that may not be contained within its training data. This helps produce more informed and precise responses to user queries.

# %%
# Using the invoke method (LangChain 1.x style)
question = "Explain Agentic AI like I'm 10."
response = qa.invoke({"query": question})
print(response["result"])
# Out:
# Agentic AI is like a smart robot that can remember things, use tools, and have goals to help it do tasks. Imagine you have a robot friend that can learn from what you tell it, use special tools like the internet to find more information, and try to achieve things you want it to do, like helping you with your homework or finding cool games to play. It's a way to make AI more helpful and capable!

# %% [markdown]
# ### Step 6: Compare Results (15–20 min)
# #### Create a table of tradeoffs:
#
# - Method Pros Cons: Best Use Fine-Tuning Highly accurate, baked-in Expensive, rigid, retrain for updates Narrow domain apps Adapters (LoRA) Cheap fine-tuning, modular Still training overhead Domain adaptation RAG Flexible, real-time knowledge Dependent on retriever quality Dynamic knowledge, frequent updates
#
# - ✅ By finishing this lab, you’ve seen the 3 main strategies to inject new knowledge into LLMs and why RAG is often the go-to for Agentic AI agents.
